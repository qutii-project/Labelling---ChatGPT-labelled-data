# %% [markdown]
# This model is to predict labels for different question and answers. The question and anwers are categorised to various categories like science and tech, analysis ,taxonomy, factual, management, strategy and  ethics and regulation.

# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings("ignore", category=DeprecationWarning)

# %%
dataset1 = pd.read_csv('/kaggle/input/labelled-solar-dataset/Solar Panel post cleaning dataset.csv', encoding='ISO-8859-1',on_bad_lines='skip')
dataset1
# Out:
#         id                                           Question  \
# 0        1            What is the main purpose of this paper?
# 1        2  What are the keywords associated with this paper?
# 2        3                                     What is GIVES?
# 3        4             What is the advantage of PV/T over PV?
# 4        7  What are the measures necessary to reduce ener...
# ...    ...                                                ...
# 2782  4283                                                NaN
# 2783  4285                                                NaN
# 2784  4286                                                NaN
# 2785  4287                                                NaN
# 2786  4289                                                NaN
#
#                                                  Answer       Label
# 0     The main purpose of this paper is to present a...    Strategy
# 1     The keywords associated with this paper are Re...    Taxonomy
# 2     GIVES stands for the integrated value model fo...    Taxonomy
# 3     PV/T is a better solution when stakeholders ar...    Strategy
# 4     Reducing energy needs with measures such as le...  Management
# ...                                                 ...         ...
# 2782                                                NaN         NaN
# 2783                                                NaN         NaN
# 2784                                                NaN         NaN
# 2785                                                NaN         NaN
# 2786                                                NaN         NaN
#
# [2787 rows x 4 columns]

# %%
dataset_1a=dataset1[["Question","Answer","Label"]]

# %%
dataset_1a = dataset_1a.dropna()

# %%
dataset_1a
# Out:
#                                                Question  \
# 0               What is the main purpose of this paper?
# 1     What are the keywords associated with this paper?
# 2                                        What is GIVES?
# 3                What is the advantage of PV/T over PV?
# 4     What are the measures necessary to reduce ener...
# ...                                                 ...
# 1999  How does Artificial Neural Network process inf...
# 2000  What are the commonly used functions in ANN st...
# 2001     What does the weighted sum equation represent?
# 2002  What is the most popular activation function u...
# 2003                  What is the process of unfolding?
#
#                                                  Answer             Label
# 0     The main purpose of this paper is to present a...          Strategy
# 1     The keywords associated with this paper are Re...          Taxonomy
# 2     GIVES stands for the integrated value model fo...          Taxonomy
# 3     PV/T is a better solution when stakeholders ar...          Strategy
# 4     Reducing energy needs with measures such as le...        Management
# ...                                                 ...               ...
# 1999  Artificial Neural Network consists of layers o...  Science and Tech
# 2000  The commonly used functions in ANN structure a...  Science and Tech
# 2001  The weighted sum equation represents the compu...  Science and Tech
# 2002  The most popular activation function used in n...  Science and Tech
# 2003  The process of unfolding refers to the process...  Science and Tech
#
# [2003 rows x 3 columns]

# %%
dataset_1b = pd.read_csv('/kaggle/input/solar-data-2/labelled_Solar_Panel_data_02_03.csv', encoding='ISO-8859-1',on_bad_lines='skip')

# %%
dataset_1b=dataset_1b[["Question","Answer","Label"]]

# %%
dataset_1b = dataset_1b.dropna()

# %%
dataset_1b
# Out:
#                                                Question  \
# 0                    What is the purpose of this study?
# 1     Why is solar energy considered a clean and ren...
# 2     What are some benefits of implementing solar e...
# 3     Which machine learning algorithm was found to ...
# 4     What is the purpose of using an ANN algorithm ...
# ...                                                 ...
# 1578  What weather conditions in Europe were respons...
# 1579  Based on the model constructed using data from...
# 1580  Despite the high share of wind energy on the I...
# 1581  Why is it almost impossible for grid operators...
# 1582  What did the study conclude about the sustaina...
#
#                                                  Answer             Label
# 0     The purpose of this study is to compare differ...          Analysis
# 1     Solar energy is considered clean because it do...           Factual
# 2     - Reduces reliance on non-renewable fossil fue...           Factual
# 3     - Artificial Neural Network (ANN) was found to...  Science and Tech
# 4     - The purpose of using an ANN algorithm is to ...          Analysis
# ...                                                 ...               ...
# 1578  The negative phase of the North Atlantic Oscil...          Analysis
# 1579  The model showed that wind energy reduced life...  Science and Tech
# 1580  Even with up to 70% wind energy on the grid, t...          Analysis
# 1581  It is almost impossible for grid operators to ...          Analysis
# 1582  The study concluded that while wind energy is ...          Analysis
#
# [1583 rows x 3 columns]

# %%
dataset_1c = pd.read_csv('/kaggle/input/test-solar-data/labelled_Solar Panel data_01.csv', encoding='ISO-8859-1',on_bad_lines='skip')

# %%
dataset_1c=dataset_1c[["Question","Answer","Label"]]

# %%
dataset_1c = dataset_1c.dropna()

# %%
dataset_1c
# Out:
#                                                Question  \
# 0     What is the main advantage of liquid air energ...
# 1           How can the efficiency of LAES be improved?
# 2     How can the Round Trip Efficiency (RTE) be imp...
# 3     How does the Solar-LAES-SE system with decoupl...
# 4     Why is implementing renewable energy-based ind...
# ...                                                 ...
# 1001  How can solar PV network installation standard...
# 1002  What are the cost estimation guidelines for so...
# 1003  What is the focus of the study presented in En...
# 1004  How does the study in J Clean Prod 2021 contri...
# 1005  How does the study in Renew Energy 2022 integr...
#
#                                                  Answer                  Label
# 0     The main advantage of LAES is that it is geogr...       Science and Tech
# 1     The efficiency of LAES can be improved by util...             Management
# 2     The Round Trip Efficiency (RTE) can be improve...             Management
# 3     The Solar-LAES-SE system with decoupled chargi...               Analysis
# 4     Implementing renewable energy-based industrial...               Strategy
# ...                                                 ...                    ...
# 1001  Solar PV network installation standards help e...  Ethics and Regulation
# 1002  Cost estimation guidelines for solar PV networ...             Management
# 1003  The focus of the study presented in Energy Pro...               Analysis
# 1004  The study in J Clean Prod 2021 contributes to ...       Science and Tech
# 1005  The study in Renew Energy 2022 integrates supp...             Management
#
# [1005 rows x 3 columns]

# %%
dataset_1d = pd.read_csv('/kaggle/input/sust-urban-dataset/labelled_Sustainable_Urban_Mobility_data_01.csv', encoding='ISO-8859-1',on_bad_lines='skip')

# %%
dataset_1d=dataset_1d[["Question","Answer","Label"]]

# %%
dataset_1d = dataset_1d.dropna()

# %%
dataset_1d
# Out:
#                                                Question  \
# 0     What is the purpose of the integrated cooling ...
# 1      How was the integrated cooling system validated?
# 2     What factors are evaluated in the study to det...
# 3     How does the proposed system under heat pump s...
# 4     What characteristics of the proposed system co...
# ...                                                 ...
# 2159  What conference did the paper "Smart Mobility:...
# 2160  What is the title of the book mentioned in ref...
# 2161  What is the topic of the paper mentioned in re...
# 2162  What is the focus of the study by Karballaeeza...
# 2163  What is the main contribution of the research ...
#
#                                                  Answer             Label
# 0     The purpose of the integrated cooling system i...          Analysis
# 1     The integrated cooling system was validated th...  Science and Tech
# 2     The study evaluates the impacts of ambient air...          Analysis
# 3     The proposed system under heat pump supplement...          Strategy
# 4     The heat and electric co-generation characteri...          Analysis
# ...                                                 ...               ...
# 2159  The paper was presented at the 2019 AEIT Inter...           Factual
# 2160  The title of the book mentioned in reference 1...           Factual
# 2161  The topic of the paper mentioned in reference ...          Analysis
# 2162  The focus of the study by Karballaeezadeh et a...          Analysis
# 2163  The main contribution of the research paper by...          Analysis
#
# [2164 rows x 3 columns]

# %%
dataset_1e = pd.read_csv('/kaggle/input/urban-mobility-2/labelled_Sustainable_Urban_Mobility_data_02.csv', encoding='ISO-8859-1',on_bad_lines='skip')

# %%
dataset_1e=dataset_1e[["Question","Answer","Label"]]

# %%
dataset_1e = dataset_1e.dropna()

# %%
dataset_1e
# Out:
#                                                Question  \
# 0     What was the European Commission's previous ap...
# 1     What were the main reasons for the European Co...
# 2     What were the recommendations made in the Comm...
# 3     What did the Council of the European Union sta...
# 4     What was the first Action identified in the Eu...
# ...                                                 ...
# 1989  What is the Sustainable Transport Plan for War...
# 1990  What is the main focus of the study "Compariso...
# 1991  What are the sources cited in the study "Compa...
# 1992  What is the significance of the Guidelines for...
# 1993  How does urban structure affect individual tra...
#
#                                                  Answer                  Label
# 0     The European Commission's previous approach to...  Ethics and Regulation
# 1     The European Commission's analysis showed that...               Analysis
# 2     The Action Plan recommended encouraging the ad...               Strategy
# 3     The Council stated that it supports the develo...  Ethics and Regulation
# 4     The first Action identified in the European Co...             Management
# ...                                                 ...                    ...
# 1989  The Sustainable Transport Plan for Warsaw is a...               Strategy
# 1990  The main focus of the study is to compare top-...               Analysis
# 1991  The sources cited in the study include Energy ...                Factual
# 1992  The Guidelines provide a framework for cities ...  Ethics and Regulation
# 1993  Urban structure has a significant influence on...               Analysis
#
# [1994 rows x 3 columns]

# %%
dataset_1f = pd.read_csv('/kaggle/input/urban-mobility-3/Sustainable Urban Mobility Dataset - extra.csv', encoding='ISO-8859-1',on_bad_lines='skip')

# %%
dataset_1f=dataset_1f[["Question","Answer","Label"]]

# %%
dataset_1f = dataset_1f.dropna()

# %%
dataset_1g = pd.read_csv('/kaggle/input/urban-mobility-4/labelled_Sustainable_Urban_Mobility_data_03.csv', encoding='ISO-8859-1',on_bad_lines='skip')
dataset_1g=dataset_1g[["Question","Answer","Label"]]
dataset_1g = dataset_1g.dropna()
dataset_1g
# Out:
#                                                Question  \
# 0     What factors contribute to increasing pollutan...
# 1     Which gases show a consistent relationship wit...
# 2     How do perceptions of potential bus users and ...
# 3     What is the potential for urban electric publi...
# 4     What is the main argument of the article "Mode...
# ...                                                 ...
# 2601  Why is assessing current mobility conditions c...
# 2602  How are indicators used to assess sustainable ...
# 2603  What are some challenges in using indicator se...
# 2604  What are some potential drawbacks of autonomou...
# 2605  How does N2O emissions compare to CO2 emission...
#
#                                                  Answer       Label
# 0     The amelioration of purchasing power, leading ...    Analysis
# 1     The gases CO2 and SPM show a consistent relati...    Analysis
# 2     Answer: The article "Perception of potential b...    Analysis
# 3     Answer: The study "Could urban electric public...    Analysis
# 4     The main argument of the article is to provide...    Analysis
# ...                                                 ...         ...
# 2601  Assessing current mobility conditions is neces...  Management
# 2602  Indicators are used to assess sustainable urba...  Management
# 2603  One of the challenges is the large number of i...  Management
# 2604  The large-scale potential of autonomous pooled...    Analysis
# 2605  N2O emissions contribute only a few percent to...    Analysis
#
# [2606 rows x 3 columns]

# %%
dataset_1h = pd.read_csv('/kaggle/input/contra-dataset/Contradictory Dataset.csv', encoding='ISO-8859-1',on_bad_lines='skip')
dataset_1h=dataset_1h[["Question","Answer","Label"]]
dataset_1h = dataset_1h.dropna()
dataset_1h
# Out:
#                                               Question  \
# 0    What is the benefit of wind forecast control i...
# 1    How do operational strategies like bid price c...
# 2    What is the purpose of Power-to-Hydrogen (P2H)...
# 3    How does P2H contribute to the integration of ...
# 4    What are some other electrofuels (P2X) that re...
# ..                                                 ...
# 190  What was the duration of the interviews and ho...
# 191  What is the role of forecasts in transport sys...
# 192  How do the interviewees propose addressing fut...
# 193  How do scenarios help in identifying possible ...
# 194  What challenges are associated with transition...
#
#                                                 Answer             Label
# 0    Wind forecast control can lead to up to 56% mo...          Analysis
# 1    Both bid price control and wind forecast contr...  Science and tech
# 2    P2H technology is used to store excess electri...  Science and tech
# 3    P2H technology helps to integrate VRE into the...  Science and tech
# 4    Some other electrofuels that rely on the elect...  Science and tech
# ..                                                 ...               ...
# 190  The interviews typically lasted around 1 hour ...           Factual
# 191  The interviewees in Stockholm believe that for...        Management
# 192  The interviewees propose implementing a broad ...        Management
# 193  Scenarios help in identifying possible paths f...        Management
# 194  Some of the challenges associated with transit...          Strategy
#
# [195 rows x 3 columns]

# %%
dataset_1i = pd.read_csv('/kaggle/input/new-data/labelled_Smart_City_data_01.csv', encoding='ISO-8859-1',on_bad_lines='skip')
dataset_1i=dataset_1i[["Question","Answer","Label"]]
dataset_1i = dataset_1i.dropna()
dataset_1i
# Out:
#                                                Question  \
# 0     What is the main strategy of Smart Cities like...
# 1     Why is the case of Barcelona of special intere...
# 2     What does the existing literature say about Ba...
# 3     What are the main components of Barcelona's Sm...
# 4     Why are governments investing in advanced infr...
# ...                                                 ...
# 1187  What measures did South Korea take to track an...
# 1188  How did South Korea flatten its coronavirus cu...
# 1189  What was the secret to South Korea's success i...
# 1190  What did the World Health Organization state r...
# 1191  What measures did the World Health Organizatio...
#
#                                                  Answer       Label
# 0     Smart Cities like Barcelona base their strateg...    Strategy
# 1     Barcelona is of special interest because it ha...    Analysis
# 2     The existing literature on Barcelona's Smart C...    Analysis
# 3     The main components of Barcelona's Smart City ...    Strategy
# 4     Governments are investing in advanced infrastr...  Management
# ...                                                 ...         ...
# 1187  South Korea implemented smartphone apps to tra...  Management
# 1188  South Korea was able to flatten its coronaviru...    Strategy
# 1189  The secret to South Korea's success in handlin...    Analysis
# 1190  The World Health Organization stated that they...     Factual
# 1191  The World Health Organization sent a team of e...  Management
#
# [1192 rows x 3 columns]

# %%
dataset_1j = pd.read_csv('/kaggle/input/new-data/labelled_Sustainable_Urban_Planning_data_01.csv', encoding='ISO-8859-1',on_bad_lines='skip')
dataset_1j=dataset_1j[["Question","Answer","Label"]]
dataset_1j = dataset_1j.dropna()
dataset_1j
# Out:
#                                                Question  \
# 0                    What is the purpose of this study?
# 1      What are the key issues addressed in this study?
# 2     What factors have contributed to the increased...
# 3     How has the urban population changed over the ...
# 4     What is the significance of sustainability in ...
# ...                                                 ...
# 2263  How does urban socio-ecology relate to the sus...
# 2264  What is the goal of the Achieving Excellence i...
# 2265  What is the purpose of the article "Internatio...
# 2266  What is the main conclusion of the article "Mo...
# 2267  How does the article "Approach to the quantifi...
#
#                                                  Answer             Label
# 0     The purpose of this study is to shed light on ...          Strategy
# 1     The key issues addressed in this study include...          Analysis
# 2     The increasing urban population and the social...           Factual
# 3     The urban population has increased nearly four...           Factual
# 4     The significance of sustainability in urban pl...          Strategy
# ...                                                 ...               ...
# 2263  Urban socio-ecology is a concept that examines...  Science and Tech
# 2264  The goal of the Achieving Excellence in Constr...          Strategy
# 2265  The purpose of the article is to compare the B...          Strategy
# 2266  The main conclusion of the article is that mod...          Analysis
# 2267  The article contributes to the field of sustai...  Science and Tech
#
# [2267 rows x 3 columns]

# %%
dataset_1k = pd.read_csv('/kaggle/input/new-data-2/labelled_Smart_City_data_02.csv', encoding='ISO-8859-1',on_bad_lines='skip')
dataset_1k =dataset_1k[["Question","Answer","Label"]]
dataset_1k = dataset_1k.dropna()
dataset_1k
# Out:
#                                                Question  \
# 0     What is the ranking of Bandung City Government...
# 1     What are the three core activities in the smar...
# 2          What research method was used in this study?
# 3      How was the analysis conducted in this research?
# 4     How many local government work units/agencies ...
# ...                                                 ...
# 4133  How can open innovation contribute to the deve...
# 4134  According to Singh (1997), what factors impact...
# 4135  What is the estimated market opportunity for s...
# 4136   What is the market opportunity for smart cities?
# 4137  Where can I find more information about the fu...
#
#                                                  Answer                  Label
# 0     Bandung City Government is ranked the 3rd in t...               Analysis
# 1     The three core activities in the smart environ...             Management
# 2     A qualitative research method was used in this...       Science and Tech
# 3     The analysis in this research was conducted us...               Analysis
# 4     Seven local government work units/departments/...             Management
# ...                                                 ...                    ...
# 4133  Open innovation encourages collaboration and s...             Management
# 4134  Technological complexity and interfirm coopera...       Science and Tech
# 4135                                     $1.5 trillion.               Analysis
# 4136  The market opportunity for smart cities is est...               Analysis
# 4137  You can find more information about the future...  Ethics and Regulation
#
# [4138 rows x 3 columns]

# %%
dataset_1 = pd.concat([dataset_1a, dataset_1b, dataset_1c, dataset_1d, dataset_1e, dataset_1f, dataset_1g, dataset_1h, dataset_1i, dataset_1j,dataset_1k], ignore_index=True)

# %%
dataset_2 = dataset_1.dropna()

# %%
dataset_2['joined_column'] = dataset_2['Question'] + ' ' + dataset_2['Answer']
dataset_3 =dataset_2[["joined_column","Label"]]

# %%
dataset_3["Label"].value_counts()
# Out:
# Label
# Analysis                 7267
# Management               3278
# Science and Tech         2879
# Strategy                 2876
# Factual                  2144
# Taxonomy                 1178
# Ethics and Regulation     939
# Science and tech          547
# Ethics and regulation     166
# Science and Tech           11
# -                           2
# Research and Tech           2
# Fa                          1
# Stra                        1
# Ethics                      1
# Definition                  1
# Name: count, dtype: int64

# %%
dataset_3 = dataset_3.replace(['Taxonomy'], 'taxonomy')
dataset_3 = dataset_3.replace([ 'Science and Tech', 'Science and Tech ','Science and tech'], 'science and tech')
dataset_3 = dataset_3.replace(['Strategy'], 'strategy')
dataset_3 = dataset_3.replace(['Management'], 'management')
dataset_3 = dataset_3.replace(['Analysis'], 'analysis')
dataset_3 = dataset_3.replace(['Factual'], 'factual')
dataset_3 = dataset_3.replace(['Ethics and regulation','Ethics and Regulation'], 'ethics and regulation')

# %%
dataset_3["Label"].value_counts()
# Out:
# Label
# analysis                 7267
# science and tech         3437
# management               3278
# strategy                 2876
# factual                  2144
# taxonomy                 1178
# ethics and regulation    1105
# -                           2
# Research and Tech           2
# Fa                          1
# Stra                        1
# Ethics                      1
# Definition                  1
# Name: count, dtype: int64

# %%
dataset_4 = dataset_3[(dataset_3["Label"] == 'strategy') |
                      (dataset_3["Label"] == 'science and tech') |
                      (dataset_3["Label"] == 'analysis') |
                      (dataset_3["Label"] == 'factual') |
                      (dataset_3["Label"] == 'taxonomy') |
                      (dataset_3["Label"] == 'management') |
                    (dataset_3["Label"] == 'ethics and regulation')]

# %%
dataset_4["Label"].value_counts()
# Out:
# Label
# analysis                 7267
# science and tech         3437
# management               3278
# strategy                 2876
# factual                  2144
# taxonomy                 1178
# ethics and regulation    1105
# Name: count, dtype: int64

# %%
dataset_4
# Out:
#                                            joined_column  \
# 0      What is the main purpose of this paper? The ma...
# 1      What are the keywords associated with this pap...
# 2      What is GIVES? GIVES stands for the integrated...
# 3      What is the advantage of PV/T over PV? PV/T is...
# 4      What are the measures necessary to reduce ener...
# ...                                                  ...
# 21288  How can open innovation contribute to the deve...
# 21289  According to Singh (1997), what factors impact...
# 21290  What is the estimated market opportunity for s...
# 21291  What is the market opportunity for smart citie...
# 21292  Where can I find more information about the fu...
#
#                        Label
# 0                   strategy
# 1                   taxonomy
# 2                   taxonomy
# 3                   strategy
# 4                 management
# ...                      ...
# 21288             management
# 21289       science and tech
# 21290               analysis
# 21291               analysis
# 21292  ethics and regulation
#
# [21285 rows x 2 columns]

# %%
import nltk
nltk.download('all')
# Out:
# [nltk_data] Downloading collection 'all'
# [nltk_data]    |
# [nltk_data]    | Downloading package abc to /usr/share/nltk_data...
# [nltk_data]    |   Package abc is already up-to-date!
# [nltk_data]    | Downloading package alpino to /usr/share/nltk_data...
# [nltk_data]    |   Package alpino is already up-to-date!
# [nltk_data]    | Downloading package averaged_perceptron_tagger to
# [nltk_data]    |     /usr/share/nltk_data...
# [nltk_data]    |   Package averaged_perceptron_tagger is already up-
# [nltk_data]    |       to-date!
# [nltk_data]    | Downloading package averaged_perceptron_tagger_ru to
# [nltk_data]    |     /usr/share/nltk_data...
# [nltk_data]    |   Package averaged_perceptron_tagger_ru is already
# [nltk_data]    |       up-to-date!
# [nltk_data]    | Downloading package basque_grammars to
# [nltk_data]    |     /usr/share/nltk_data...
# [nltk_data]    |   Package basque_grammars is already up-to-date!
# [nltk_data]    | Downloading package bcp47 to /usr/share/nltk_data...
# [nltk_data]    |   Package bcp47 is already up-to-date!
# [nltk_data]    | Downloading package biocreative_ppi to
# [nltk_data]    |     /usr/share/nltk_data...
# [nltk_data]    |   Package biocreative_ppi is already up-to-date!
# [nltk_data]    | Downloading package bllip_wsj_no_aux to
# [nltk_data]    |     /usr/share/nltk_data...
# [nltk_data]    |   Package bllip_wsj_no_aux is already up-to-date!
# [nltk_data]    | Downloading package book_grammars to
# [nltk_data]    |     /usr/share/nltk_data...
# [nltk_data]    |   Package book_grammars is already up-to-date!
# [nltk_data]    | Downloading package brown to /usr/share/nltk_data...
# [nltk_data]    |   Package brown is already up-to-date!
# [nltk_data]    | Downloading package brown_tei to
# [nltk_data]    |     /usr/share/nltk_data...
# [nltk_data]    |   Package brown_tei is already up-to-date!
# [nltk_data]    | Downloading package cess_cat to
# [nltk_data]    |     /usr/share/nltk_data...
# [nltk_data]    |   Package cess_cat is already up-to-date!
# [nltk_data]    | Downloading package cess_esp to
# [nltk_data]    |     /usr/share/nltk_data...
# [nltk_data]    |   Package cess_esp is already up-to-date!
# [nltk_data]    | Downloading package chat80 to /usr/share/nltk_data...
# [nltk_data]    |   Package chat80 is already up-to-date!
# [nltk_data]    | Downloading package city_database to
# [nltk_data]    |     /usr/share/nltk_data...
# [nltk_data]    |   Package city_database is already up-to-date!
# [nltk_data]    | Downloading package cmudict to
# [nltk_data]    |     /usr/share/nltk_data...
# [nltk_data]    |   Package cmudict is already up-to-date!
# [nltk_data]    | Downloading package comparative_sentences to
# [nltk_data]    |     /usr/share/nltk_data...
# [nltk_data]    |   Package comparative_sentences is already up-to-
# [nltk_data]    |       date!
# [nltk_data]    | Downloading package comtrans to
# [nltk_data]    |     /usr/share/nltk_data...
# [nltk_data]    |   Package comtrans is already up-to-date!
# [nltk_data]    | Downloading package conll2000 to
# [nltk_data]    |     /usr/share/nltk_data...
# [nltk_data]    |   Package conll2000 is already up-to-date!
# [nltk_data]    | Downloading package conll2002 to
# [nltk_data]    |     /usr/share/nltk_data...
# [nltk_data]    |   Package conll2002 is already up-to-date!
# [nltk_data]    | Downloading package conll2007 to
# [nltk_data]    |     /usr/share/nltk_data...
# [nltk_data]    |   Package conll2007 is already up-to-date!
# [nltk_data]    | Downloading package crubadan to
# [nltk_data]    |     /usr/share/nltk_data...
# [nltk_data]    |   Package crubadan is already up-to-date!
# [nltk_data]    | Downloading package dependency_treebank to
# [nltk_data]    |     /usr/share/nltk_data...
# [nltk_data]    |   Package dependency_treebank is already up-to-date!
# [nltk_data]    | Downloading package dolch to /usr/share/nltk_data...
# [nltk_data]    |   Package dolch is already up-to-date!
# [nltk_data]    | Downloading package europarl_raw to
# [nltk_data]    |     /usr/share/nltk_data...
# [nltk_data]    |   Package europarl_raw is already up-to-date!
# [nltk_data]    | Downloading package extended_omw to
# [nltk_data]    |     /usr/share/nltk_data...
# [nltk_data]    |   Package extended_omw is already up-to-date!
# [nltk_data]    | Downloading package floresta to
# [nltk_data]    |     /usr/share/nltk_data...
# [nltk_data]    |   Package floresta is already up-to-date!
# [nltk_data]    | Downloading package framenet_v15 to
# [nltk_data]    |     /usr/share/nltk_data...
# [nltk_data]    |   Package framenet_v15 is already up-to-date!
# [nltk_data]    | Downloading package framenet_v17 to
# [nltk_data]    |     /usr/share/nltk_data...
# [nltk_data]    |   Package framenet_v17 is already up-to-date!
# [nltk_data]    | Downloading package gazetteers to
# [nltk_data]    |     /usr/share/nltk_data...
# [nltk_data]    |   Package gazetteers is already up-to-date!
# [nltk_data]    | Downloading package genesis to
# [nltk_data]    |     /usr/share/nltk_data...
# [nltk_data]    |   Package genesis is already up-to-date!
# [nltk_data]    | Downloading package gutenberg to
# [nltk_data]    |     /usr/share/nltk_data...
# [nltk_data]    |   Package gutenberg is already up-to-date!
# [nltk_data]    | Downloading package ieer to /usr/share/nltk_data...
# [nltk_data]    |   Package ieer is already up-to-date!
# [nltk_data]    | Downloading package inaugural to
# [nltk_data]    |     /usr/share/nltk_data...
# [nltk_data]    |   Package inaugural is already up-to-date!
# [nltk_data]    | Downloading package indian to /usr/share/nltk_data...
# [nltk_data]    |   Package indian is already up-to-date!
# [nltk_data]    | Downloading package jeita to /usr/share/nltk_data...
# [nltk_data]    |   Package jeita is already up-to-date!
# [nltk_data]    | Downloading package kimmo to /usr/share/nltk_data...
# [nltk_data]    |   Package kimmo is already up-to-date!
# [nltk_data]    | Downloading package knbc to /usr/share/nltk_data...
# [nltk_data]    |   Package knbc is already up-to-date!
# [nltk_data]    | Downloading package large_grammars to
# [nltk_data]    |     /usr/share/nltk_data...
# [nltk_data]    |   Package large_grammars is already up-to-date!
# [nltk_data]    | Downloading package lin_thesaurus to
# [nltk_data]    |     /usr/share/nltk_data...
# [nltk_data]    |   Package lin_thesaurus is already up-to-date!
# [nltk_data]    | Downloading package mac_morpho to
# [nltk_data]    |     /usr/share/nltk_data...
# [nltk_data]    |   Package mac_morpho is already up-to-date!
# [nltk_data]    | Downloading package machado to
# [nltk_data]    |     /usr/share/nltk_data...
# [nltk_data]    |   Package machado is already up-to-date!
# [nltk_data]    | Downloading package masc_tagged to
# [nltk_data]    |     /usr/share/nltk_data...
# [nltk_data]    |   Package masc_tagged is already up-to-date!
# [nltk_data]    | Downloading package maxent_ne_chunker to
# [nltk_data]    |     /usr/share/nltk_data...
# [nltk_data]    |   Package maxent_ne_chunker is already up-to-date!
# [nltk_data]    | Downloading package maxent_treebank_pos_tagger to
# [nltk_data]    |     /usr/share/nltk_data...
# [nltk_data]    |   Package maxent_treebank_pos_tagger is already up-
# [nltk_data]    |       to-date!
# [nltk_data]    | Downloading package moses_sample to
# [nltk_data]    |     /usr/share/nltk_data...
# [nltk_data]    |   Package moses_sample is already up-to-date!
# [nltk_data]    | Downloading package movie_reviews to
# [nltk_data]    |     /usr/share/nltk_data...
# [nltk_data]    |   Package movie_reviews is already up-to-date!
# [nltk_data]    | Downloading package mte_teip5 to
# [nltk_data]    |     /usr/share/nltk_data...
# [nltk_data]    |   Package mte_teip5 is already up-to-date!
# [nltk_data]    | Downloading package mwa_ppdb to
# [nltk_data]    |     /usr/share/nltk_data...
# [nltk_data]    |   Package mwa_ppdb is already up-to-date!
# [nltk_data]    | Downloading package names to /usr/share/nltk_data...
# [nltk_data]    |   Package names is already up-to-date!
# [nltk_data]    | Downloading package nombank.1.0 to
# [nltk_data]    |     /usr/share/nltk_data...
# [nltk_data]    |   Package nombank.1.0 is already up-to-date!
# [nltk_data]    | Downloading package nonbreaking_prefixes to
# [nltk_data]    |     /usr/share/nltk_data...
# [nltk_data]    |   Package nonbreaking_prefixes is already up-to-date!
# [nltk_data]    | Downloading package nps_chat to
# [nltk_data]    |     /usr/share/nltk_data...
# [nltk_data]    |   Package nps_chat is already up-to-date!
# [nltk_data]    | Downloading package omw to /usr/share/nltk_data...
# [nltk_data]    |   Package omw is already up-to-date!
# [nltk_data]    | Downloading package omw-1.4 to
# [nltk_data]    |     /usr/share/nltk_data...
# [nltk_data]    |   Package omw-1.4 is already up-to-date!
# [nltk_data]    | Downloading package opinion_lexicon to
# [nltk_data]    |     /usr/share/nltk_data...
# [nltk_data]    |   Package opinion_lexicon is already up-to-date!
# [nltk_data]    | Downloading package panlex_swadesh to
# [nltk_data]    |     /usr/share/nltk_data...
# [nltk_data]    |   Package panlex_swadesh is already up-to-date!
# [nltk_data]    | Downloading package paradigms to
# [nltk_data]    |     /usr/share/nltk_data...
# [nltk_data]    |   Package paradigms is already up-to-date!
# [nltk_data]    | Downloading package pe08 to /usr/share/nltk_data...
# [nltk_data]    |   Package pe08 is already up-to-date!
# [nltk_data]    | Downloading package perluniprops to
# [nltk_data]    |     /usr/share/nltk_data...
# [nltk_data]    |   Package perluniprops is already up-to-date!
# [nltk_data]    | Downloading package pil to /usr/share/nltk_data...
# [nltk_data]    |   Package pil is already up-to-date!
# [nltk_data]    | Downloading package pl196x to /usr/share/nltk_data...
# [nltk_data]    |   Package pl196x is already up-to-date!
# [nltk_data]    | Downloading package porter_test to
# [nltk_data]    |     /usr/share/nltk_data...
# [nltk_data]    |   Package porter_test is already up-to-date!
# [nltk_data]    | Downloading package ppattach to
# [nltk_data]    |     /usr/share/nltk_data...
# [nltk_data]    |   Package ppattach is already up-to-date!
# [nltk_data]    | Downloading package problem_reports to
# [nltk_data]    |     /usr/share/nltk_data...
# [nltk_data]    |   Package problem_reports is already up-to-date!
# [nltk_data]    | Downloading package product_reviews_1 to
# [nltk_data]    |     /usr/share/nltk_data...
# [nltk_data]    |   Package product_reviews_1 is already up-to-date!
# [nltk_data]    | Downloading package product_reviews_2 to
# [nltk_data]    |     /usr/share/nltk_data...
# [nltk_data]    |   Package product_reviews_2 is already up-to-date!
# [nltk_data]    | Downloading package propbank to
# [nltk_data]    |     /usr/share/nltk_data...
# [nltk_data]    |   Package propbank is already up-to-date!
# [nltk_data]    | Downloading package pros_cons to
# [nltk_data]    |     /usr/share/nltk_data...
# [nltk_data]    |   Package pros_cons is already up-to-date!
# [nltk_data]    | Downloading package ptb to /usr/share/nltk_data...
# [nltk_data]    |   Package ptb is already up-to-date!
# [nltk_data]    | Downloading package punkt to /usr/share/nltk_data...
# [nltk_data]    |   Package punkt is already up-to-date!
# [nltk_data]    | Downloading package qc to /usr/share/nltk_data...
# [nltk_data]    |   Package qc is already up-to-date!
# [nltk_data]    | Downloading package reuters to
# [nltk_data]    |     /usr/share/nltk_data...
# [nltk_data]    |   Package reuters is already up-to-date!
# [nltk_data]    | Downloading package rslp to /usr/share/nltk_data...
# [nltk_data]    |   Package rslp is already up-to-date!
# [nltk_data]    | Downloading package rte to /usr/share/nltk_data...
# [nltk_data]    |   Package rte is already up-to-date!
# [nltk_data]    | Downloading package sample_grammars to
# [nltk_data]    |     /usr/share/nltk_data...
# [nltk_data]    |   Package sample_grammars is already up-to-date!
# [nltk_data]    | Downloading package semcor to /usr/share/nltk_data...
# [nltk_data]    |   Package semcor is already up-to-date!
# [nltk_data]    | Downloading package senseval to
# [nltk_data]    |     /usr/share/nltk_data...
# [nltk_data]    |   Package senseval is already up-to-date!
# [nltk_data]    | Downloading package sentence_polarity to
# [nltk_data]    |     /usr/share/nltk_data...
# [nltk_data]    |   Package sentence_polarity is already up-to-date!
# [nltk_data]    | Downloading package sentiwordnet to
# [nltk_data]    |     /usr/share/nltk_data...
# [nltk_data]    |   Package sentiwordnet is already up-to-date!
# [nltk_data]    | Downloading package shakespeare to
# [nltk_data]    |     /usr/share/nltk_data...
# [nltk_data]    |   Package shakespeare is already up-to-date!
# [nltk_data]    | Downloading package sinica_treebank to
# [nltk_data]    |     /usr/share/nltk_data...
# [nltk_data]    |   Package sinica_treebank is already up-to-date!
# [nltk_data]    | Downloading package smultron to
# [nltk_data]    |     /usr/share/nltk_data...
# [nltk_data]    |   Package smultron is already up-to-date!
# [nltk_data]    | Downloading package snowball_data to
# [nltk_data]    |     /usr/share/nltk_data...
# [nltk_data]    |   Package snowball_data is already up-to-date!
# [nltk_data]    | Downloading package spanish_grammars to
# [nltk_data]    |     /usr/share/nltk_data...
# [nltk_data]    |   Package spanish_grammars is already up-to-date!
# [nltk_data]    | Downloading package state_union to
# [nltk_data]    |     /usr/share/nltk_data...
# [nltk_data]    |   Package state_union is already up-to-date!
# [nltk_data]    | Downloading package stopwords to
# [nltk_data]    |     /usr/share/nltk_data...
# [nltk_data]    |   Package stopwords is already up-to-date!
# [nltk_data]    | Downloading package subjectivity to
# [nltk_data]    |     /usr/share/nltk_data...
# [nltk_data]    |   Package subjectivity is already up-to-date!
# [nltk_data]    | Downloading package swadesh to
# [nltk_data]    |     /usr/share/nltk_data...
# [nltk_data]    |   Package swadesh is already up-to-date!
# [nltk_data]    | Downloading package switchboard to
# [nltk_data]    |     /usr/share/nltk_data...
# [nltk_data]    |   Package switchboard is already up-to-date!
# [nltk_data]    | Downloading package tagsets to
# [nltk_data]    |     /usr/share/nltk_data...
# [nltk_data]    |   Package tagsets is already up-to-date!
# [nltk_data]    | Downloading package timit to /usr/share/nltk_data...
# [nltk_data]    |   Package timit is already up-to-date!
# [nltk_data]    | Downloading package toolbox to
# [nltk_data]    |     /usr/share/nltk_data...
# [nltk_data]    |   Package toolbox is already up-to-date!
# [nltk_data]    | Downloading package treebank to
# [nltk_data]    |     /usr/share/nltk_data...
# [nltk_data]    |   Package treebank is already up-to-date!
# [nltk_data]    | Downloading package twitter_samples to
# [nltk_data]    |     /usr/share/nltk_data...
# [nltk_data]    |   Package twitter_samples is already up-to-date!
# [nltk_data]    | Downloading package udhr to /usr/share/nltk_data...
# [nltk_data]    |   Package udhr is already up-to-date!
# [nltk_data]    | Downloading package udhr2 to /usr/share/nltk_data...
# [nltk_data]    |   Package udhr2 is already up-to-date!
# [nltk_data]    | Downloading package unicode_samples to
# [nltk_data]    |     /usr/share/nltk_data...
# [nltk_data]    |   Package unicode_samples is already up-to-date!
# [nltk_data]    | Downloading package universal_tagset to
# [nltk_data]    |     /usr/share/nltk_data...
# [nltk_data]    |   Package universal_tagset is already up-to-date!
# [nltk_data]    | Downloading package universal_treebanks_v20 to
# [nltk_data]    |     /usr/share/nltk_data...
# [nltk_data]    |   Package universal_treebanks_v20 is already up-to-
# [nltk_data]    |       date!
# [nltk_data]    | Downloading package vader_lexicon to
# [nltk_data]    |     /usr/share/nltk_data...
# [nltk_data]    |   Package vader_lexicon is already up-to-date!
# [nltk_data]    | Downloading package verbnet to
# [nltk_data]    |     /usr/share/nltk_data...
# [nltk_data]    |   Package verbnet is already up-to-date!
# [nltk_data]    | Downloading package verbnet3 to
# [nltk_data]    |     /usr/share/nltk_data...
# [nltk_data]    |   Package verbnet3 is already up-to-date!
# [nltk_data]    | Downloading package webtext to
# [nltk_data]    |     /usr/share/nltk_data...
# [nltk_data]    |   Package webtext is already up-to-date!
# [nltk_data]    | Downloading package wmt15_eval to
# [nltk_data]    |     /usr/share/nltk_data...
# [nltk_data]    |   Package wmt15_eval is already up-to-date!
# [nltk_data]    | Downloading package word2vec_sample to
# [nltk_data]    |     /usr/share/nltk_data...
# [nltk_data]    |   Package word2vec_sample is already up-to-date!
# [nltk_data]    | Downloading package wordnet to
# [nltk_data]    |     /usr/share/nltk_data...
# [nltk_data]    |   Package wordnet is already up-to-date!
# [nltk_data]    | Downloading package wordnet2021 to
# [nltk_data]    |     /usr/share/nltk_data...
# [nltk_data]    |   Package wordnet2021 is already up-to-date!
# [nltk_data]    | Downloading package wordnet2022 to
# [nltk_data]    |     /usr/share/nltk_data...
# [nltk_data]    |   Package wordnet2022 is already up-to-date!
# [nltk_data]    | Downloading package wordnet31 to
# [nltk_data]    |     /usr/share/nltk_data...
# [nltk_data]    |   Package wordnet31 is already up-to-date!
# [nltk_data]    | Downloading package wordnet_ic to
# [nltk_data]    |     /usr/share/nltk_data...
# [nltk_data]    |   Package wordnet_ic is already up-to-date!
# [nltk_data]    | Downloading package words to /usr/share/nltk_data...
# [nltk_data]    |   Package words is already up-to-date!
# [nltk_data]    | Downloading package ycoe to /usr/share/nltk_data...
# [nltk_data]    |   Package ycoe is already up-to-date!
# [nltk_data]    |
# [nltk_data]  Done downloading collection all
# True

# %%
import re

from nltk.corpus import stopwords

from nltk.tokenize import word_tokenize

from nltk.stem import WordNetLemmatizer

lemmatizer = WordNetLemmatizer() # lemma

import spacy

nlp = spacy.load('en_core_web_sm')

corpus = []

text = list(dataset_4['joined_column']) # for cleaning purposes

numwords = {
    "zero": 0, "one": 1, "two": 2, "three": 3, "four": 4, "five": 5, "six": 6, "seven": 7, "eight": 8, "nine": 9,
    "ten": 10, "eleven": 11, "twelve": 12, "thirteen": 13, "fourteen": 14, "fifteen": 15, "sixteen": 16,
    "seventeen": 17, "eighteen": 18, "nineteen": 19,
    "twenty": 20, "thirty": 30, "forty": 40, "fifty": 50, "sixty": 60, "seventy": 70, "eighty": 80, "ninety": 90,
    "hundred": 100, "thousand": 1000, "million": 1000000, "billion": 1000000000, "trillion": 1000000000000,
}

for i in range(len(text)):

    r = re.sub('[^a-zA-Z]', ' ', text[i])
    r = re.sub(r"(\w)([.,;:!?'\"”\)])", r"\1 \2", text[i])
    r = re.sub(r"(\w)([.,;:!?'\"”\)])", r"\1 \2", text[i])
    
    r = re.sub(r"n\'t", " not", r)
    r = re.sub(r"\'re", " are", r)
    r = re.sub(r"\'s", " is", r)
    r = re.sub(r"\'d", " would", r)
    r = re.sub(r"\'ll", " will", r)
    r = re.sub(r"\'t", " not", r)
    r = re.sub(r"\'ve", " have", r)
    r = re.sub(r"\'m", " am", r)

    r = re.sub(r"n\’t", " not", r)
    r = re.sub(r"\’re", " are", r)
    r = re.sub(r"\’s", " is", r)
    r = re.sub(r"\’d", " would", r)
    r = re.sub(r"\’ll", " will", r)
    r = re.sub(r"\’t", " not", r)
    r = re.sub(r"\’ve", " have", r)
    r = re.sub(r"\’m", " am", r)
    
    # Convert text to integer
    textnum = r.replace('-', ' ')
    words = textnum.split()
    result = 0
    current = 0

    for word in words:
        if word in numwords:
            num = numwords[word]
            if num == 100:
                current *= num
            else:
                current += num
        elif word == 'and':
            continue
        else:
            if current != 0:
                result += current
                current = 0

    r = r.lower()

    r = r.split()

    r = [word for word in r if word not in stopwords.words('english')]

    doc = nlp(text[i])
    
    r = [token.lemma_ for token in doc]

    r = ' '.join(r)

    corpus.append(r)

# %%
# !pip install spacy
# Out:
# Requirement already satisfied: spacy in /opt/conda/lib/python3.10/site-packages (3.7.2)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /opt/conda/lib/python3.10/site-packages (from spacy) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /opt/conda/lib/python3.10/site-packages (from spacy) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /opt/conda/lib/python3.10/site-packages (from spacy) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /opt/conda/lib/python3.10/site-packages (from spacy) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /opt/conda/lib/python3.10/site-packages (from spacy) (3.0.9)
# Requirement already satisfied: thinc<8.3.0,>=8.1.8 in /opt/conda/lib/python3.10/site-packages (from spacy) (8.2.1)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /opt/conda/lib/python3.10/site-packages (from spacy) (1.1.2)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /opt/conda/lib/python3.10/site-packages (from spacy) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /opt/conda/lib/python3.10/site-packages (from spacy) (2.0.10)
# Requirement already satisfied: weasel<0.4.0,>=0.1.0 in /opt/conda/lib/python3.10/site-packages (from spacy) (0.3.4)
# Requirement already satisfied: typer<0.10.0,>=0.3.0 in /opt/conda/lib/python3.10/site-packages (from spacy) (0.9.0)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in /opt/conda/lib/python3.10/site-packages (from spacy) (6.3.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /opt/conda/lib/python3.10/site-packages (from spacy) (4.66.1)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /opt/conda/lib/python3.10/site-packages (from spacy) (2.31.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /opt/conda/lib/python3.10/site-packages (from spacy) (1.10.12)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.10/site-packages (from spacy) (3.1.2)
# Requirement already satisfied: setuptools in /opt/conda/lib/python3.10/site-packages (from spacy) (68.1.2)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/lib/python3.10/site-packages (from spacy) (21.3)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /opt/conda/lib/python3.10/site-packages (from spacy) (3.3.0)
# Requirement already satisfied: numpy>=1.19.0 in /opt/conda/lib/python3.10/site-packages (from spacy) (1.24.3)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /opt/conda/lib/python3.10/site-packages (from packaging>=20.0->spacy) (3.0.9)
# Requirement already satisfied: typing-extensions>=4.2.0 in /opt/conda/lib/python3.10/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (4.5.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests<3.0.0,>=2.13.0->spacy) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests<3.0.0,>=2.13.0->spacy) (2023.7.22)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /opt/conda/lib/python3.10/site-packages (from thinc<8.3.0,>=8.1.8->spacy) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /opt/conda/lib/python3.10/site-packages (from thinc<8.3.0,>=8.1.8->spacy) (0.1.3)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /opt/conda/lib/python3.10/site-packages (from typer<0.10.0,>=0.3.0->spacy) (8.1.7)
# Requirement already satisfied: cloudpathlib<0.17.0,>=0.7.0 in /opt/conda/lib/python3.10/site-packages (from weasel<0.4.0,>=0.1.0->spacy) (0.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.10/site-packages (from jinja2->spacy) (2.1.3)

# %%
dataset_4['joined_column'] = corpus

dataset_4.head()
# Out:
# /tmp/ipykernel_47/3746401846.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataset_4['joined_column'] = corpus
#                                        joined_column       Label
# 0  what be the main purpose of this paper ? the m...    strategy
# 1  what be the keyword associate with this paper ...    taxonomy
# 2  what be GIVES ? GIVES stand for the integrate ...    taxonomy
# 3  what be the advantage of PV / T over pv ? pv /...    strategy
# 4  what be the measure necessary to reduce energy...  management

# %%
dataset_4.shape
# Out:
# (21285, 2)

# %%
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score,classification_report,make_scorer
from sklearn.preprocessing import LabelEncoder


# Preprocessing steps
X = dataset_4['joined_column']
y = dataset_4['Label']

# Encode the target variable
label_encoder = LabelEncoder()
y_encoded = label_encoder.fit_transform(y)

# Create a TF-IDF vectorizer
tfidf_vectorizer = TfidfVectorizer(max_features=1000)
X_tfidf = tfidf_vectorizer.fit_transform(X)

# %%
# !pip install transformers

# %%
from transformers import BertTokenizer, BertModel
from nltk.tokenize import word_tokenize
from sklearn.feature_extraction import DictVectorizer
from scipy.sparse import hstack 
from gensim.models import Word2Vec
from scipy.sparse import csr_matrix


import torch
X_feature_vectors = []  # Store the feature vectors for X

for text in X:
    #tokens = text.split() 
    tokens = word_tokenize(text)
    feature_dict = {}  # Local feature vector in dict form
    for w in tokens:
        if w in feature_dict:
            feature_dict[w] = feature_dict[w] + 1  # Add weight based on occurrence
        else:
            feature_dict[w] = 1  # Assigning 1 to word weight
    X_feature_vectors.append(feature_dict)

# Convert X_feature_vectors into a sparse matrix

dict_vectorizer = DictVectorizer(sparse=True)
X_custom_features = dict_vectorizer.fit_transform(X_feature_vectors)

# Load BERT tokenizer and model
tokenizer = BertTokenizer.from_pretrained('bert-base-uncased')
model = BertModel.from_pretrained('bert-base-uncased')

# Initialize a list to store BERT embeddings
X_bert_embeddings = []

for text in X:
    # Tokenize the text using BERT tokenizer
    tokens = tokenizer(text, padding=True, truncation=True, return_tensors="pt")
    
    # Pass the tokens through the BERT model to obtain embeddings
    with torch.no_grad():
        outputs = model(**tokens)
    
    # Extract the embeddings for the [CLS] token (you can use other tokens as well)
    embeddings = outputs.last_hidden_state.mean(dim=1).squeeze().numpy()
    
    X_bert_embeddings.append(embeddings)
    
# Convert X_bert_embeddings into a 2-D NumPy array
X_bert_embeddings_array = np.array(X_bert_embeddings)

# Create a sparse matrix from the NumPy array
X_bert_embeddings_sparse = csr_matrix(X_bert_embeddings_array)

# %%
import gensim.downloader as api

# GloVe embeddings
glove_model = api.load("glove-wiki-gigaword-100")
glove_size = 100  # You can change this based on the downloaded GloVe model

X_glove_embeddings = []

for text in X:
    tokens = word_tokenize(text)
    embeddings = [glove_model[token] for token in tokens if token in glove_model]
    if embeddings:
        avg_embedding = sum(embeddings) / len(embeddings)
        X_glove_embeddings.append(avg_embedding)
    else:
        X_glove_embeddings.append([0.0] * glove_size)

X_glove_embeddings = np.array(X_glove_embeddings)
X_glove_embeddings_sparse = csr_matrix(X_glove_embeddings)

# %%
from sklearn.feature_extraction.text import CountVectorizer
# Bag-of-Words (BoW) features
count_vectorizer = CountVectorizer(max_features=1000)
X_bow = count_vectorizer.fit_transform(X)

# %%
# Tokenize your text using NLTK
X_tokenized = [word_tokenize(text) for text in X]

# Train a Word2Vec model on your tokenized text
w2v_model = Word2Vec(sentences=X_tokenized, vector_size=100, window=5, min_count=1, sg=0)

# Initialize a list to store Word2Vec embeddings
X_w2v_embeddings = []

for tokens in X_tokenized:
    # Calculate the average embedding for the tokens in each text
    embeddings = [w2v_model.wv[token] for token in tokens if token in w2v_model.wv]
    if embeddings:
        avg_embedding = sum(embeddings) / len(embeddings)
        X_w2v_embeddings.append(avg_embedding)
    else:
        # If no tokens are in the Word2Vec vocabulary, add a placeholder vector
        X_w2v_embeddings.append([0.0] * w2v_model.vector_size)

# Convert X_bert_embeddings into a 2-D NumPy array
X_w2v_embeddings = np.array(X_w2v_embeddings)

# Convert X_w2v_embeddings into a sparse matrix
X_w2v_embeddings = csr_matrix(X_w2v_embeddings)

# %%
# Combine TF-IDF features, custom features, and Word2Vec embeddings into a single sparse matrix
X_combined = hstack([X_tfidf, X_custom_features, X_w2v_embeddings, X_bert_embeddings_sparse,X_bow,X_glove_embeddings_sparse])

# %%
 X_combined.shape

# %%
# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X_combined, y_encoded, test_size=0.3 ,random_state=42)

# %%
# Import necessary libraries

from sklearn.metrics import accuracy_score, classification_report
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import LogisticRegression


# Define a list of classifiers
classifiers = [
    RandomForestClassifier(),
    GradientBoostingClassifier(),
    SVC(),
    KNeighborsClassifier(),
    LogisticRegression()
]

# Train and evaluate each classifier
for classifier in classifiers:
    # Train the classifier
    classifier.fit(X_train, y_train)

    # Make predictions
    y_pred = classifier.predict(X_test)

    # Evaluate performance
    accuracy = accuracy_score(y_test, y_pred)
    report = classification_report(y_test, y_pred)

    # Display results
    print(f"\n{classifier.__class__.__name__} Results:")
    print(f"Accuracy: {accuracy:.4f}")
    print(f"Classification Report:\n{report}")

# %%
from sklearn.ensemble import VotingClassifier
from sklearn.linear_model import LogisticRegression
from xgboost import XGBClassifier
from sklearn.svm import SVC
from sklearn.utils.class_weight import compute_class_weight

svc = SVC(probability=True)

xgboost = XGBClassifier(
    n_estimators=300,
    max_depth=3,
    learning_rate=0.1,
    min_child_weight=2,
    subsample=0.9,
    colsample_bytree=0.8,
    alpha=1,
    gamma=0,
    reg_lambda=2  # 'lambda' is a reserved keyword, use 'reg_lambda' instead
)

# %%
from sklearn.model_selection import train_test_split
from imblearn.over_sampling import SMOTE
from sklearn.preprocessing import LabelEncoder
import numpy as np

# Identify minority classes
minority_classes = ["taxonomy", "ethics and regulation"]

# Filter instances belonging to minority classes
minority_indices = np.isin(label_encoder.classes_, minority_classes)
minority_class_labels = label_encoder.transform(minority_classes)
X_train_minority = X_train[np.isin(y_train, minority_class_labels)]

# Separate majority and minority instances
X_majority = X_train[~np.isin(y_train, minority_class_labels)]
y_majority = y_train[~np.isin(y_train, minority_class_labels)]

# Print shapes before SMOTE transformation
print("Before SMOTE transformation:")
print("Majority class shape:", X_majority.shape)
print("Minority class shape:", X_minority_resampled.shape)
# Out:
# Before SMOTE transformation:
# Majority class shape: (13333, 1000)
# Minority class shape: (13332, 1000)

# %%
# Resample only the minority class instances using SMOTE
desired_minority_ratio = 0.5  # Adjust this ratio based on your preference
# Convert sparse matrices to dense arrays
#X_majority_dense = X_majority.toarray()

# Calculate the length of the minority class
minority_length = int(desired_minority_ratio * X_majority.shape[0])

smote = SMOTE(sampling_strategy={1: minority_length, 6: minority_length}, random_state=42)


X_minority_resampled, y_minority_resampled = smote.fit_resample(X_train_minority, y_train[np.isin(y_train, minority_class_labels)])
# Combine the resampled minority instances with the original majority instances
X_train_resampled = np.concatenate([X_majority.toarray(), X_minority_resampled.toarray()])
y_train_resampled = np.hstack([y_majority, y_minority_resampled])

# %%
# Print shapes after SMOTE transformation
print("\nAfter SMOTE transformation:")
print("Majority class shape:", X_majority.shape)
print("Minority class shape:", X_minority_resampled.shape)
print("Class Distribution in y_train_resampled:", np.bincount(y_train_resampled))
# Out:
# After SMOTE transformation:
# Majority class shape: (13333, 1000)
# Minority class shape: (13332, 1000)
# Class Distribution in y_train_resampled: [5044 6666 1567 2300 2400 2022 6666]

# %%
class_weights = compute_class_weight('balanced', classes=np.unique(y_train_resampled), y=y_train_resampled)
print("Class Weights:", class_weights)
print("Unique Classes in y_train_resampled:", np.unique(y_train_resampled))
# Out:
# Class Weights: [0.75521128 0.57145    2.43094174 1.65621118 1.58720238 1.88391974
#  0.57145   ]
# Unique Classes in y_train_resampled: [0 1 2 3 4 5 6]

# %%
# Update logistic regression model with class weights
logistic_regression = LogisticRegression(
    class_weight= dict(zip(np.unique(y_train_resampled), class_weights)),
    warm_start=True,
    C=1,
    fit_intercept=False,
    penalty='l2',
    max_iter=50,
    multi_class='multinomial',
    solver='saga'
)

# Create an ensemble model using VotingClassifier
ensemble_model = VotingClassifier(
    estimators=[('logistic_regression', logistic_regression), ('xgboost', xgboost), ('svc', svc) ],
    voting='soft'  # Use soft voting for probability-based predictions
)

# Fit the ensemble model to the resampled training data
ensemble_model.fit(X_train_resampled, y_train_resampled)
X_test_dense = X_test.toarray()

# Make predictions on the test set using the ensemble model
y_pred = ensemble_model.predict(X_test_dense)

# %%
# Calculate evaluation metrics
accuracy = accuracy_score(y_test, y_pred)
precision = precision_score(y_test, y_pred, average='weighted', zero_division=0)
recall = recall_score(y_test, y_pred, average='weighted')
f1 = f1_score(y_test, y_pred, average='weighted', zero_division=0)
classification_rep = classification_report(y_test, y_pred, target_names=label_encoder.classes_, zero_division=0)

metrics = {
    'Accuracy': accuracy,
    'Precision': precision,
    'Recall': recall,
    'F1': f1,
    'Classification Report': classification_rep
}

print(f'Accuracy: {metrics["Accuracy"]:.4f}')
print(f'Precision: {metrics["Precision"]:.4f}')
print(f'Recall: {metrics["Recall"]:.4f}')
print(f'F1-score: {metrics["F1"]:.4f}')
print(f'Classification Report:\n{metrics["Classification Report"]}')
# Out:
# Accuracy: 0.5376
# Precision: 0.5308
# Recall: 0.5376
# F1-score: 0.5325
# Classification Report:
#                        precision    recall  f1-score   support
#
#              analysis       0.63      0.70      0.66      2223
# ethics and regulation       0.50      0.38      0.43       348
#               factual       0.50      0.52      0.51       577
#            management       0.44      0.37      0.40       978
#      science and tech       0.53      0.54      0.54      1037
#              strategy       0.46      0.42      0.44       854
#              taxonomy       0.41      0.42      0.42       369
#
#              accuracy                           0.54      6386
#             macro avg       0.50      0.48      0.49      6386
#          weighted avg       0.53      0.54      0.53      6386

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
import matplotlib.pyplot as plt

# Define your labels as a list of strings
labels = ['analysis', 'science and tech', 'factual', 'taxonomy', 'strategy','ethics and regulation', 'management']

# Assuming y_test contains the true labels for the test set and y_pred contains predicted labels
# Define a mapping from numerical labels to string labels
label_mapping = {i: label for i, label in enumerate(labels)}

# Use list comprehension to convert numerical labels to string labels
y_test_strings = [label_mapping[label] for label in y_test]
y_pred_strings = [label_mapping[label] for label in y_pred]

confusion = confusion_matrix(y_test_strings, y_pred_strings)
disp = ConfusionMatrixDisplay(confusion_matrix=confusion, display_labels=labels)

# Rotate the x-axis labels for better alignment
disp.plot(cmap='viridis', xticks_rotation='vertical')

plt.show()

# %%
#dataset_1c = pd.read_csv('test.csv', encoding='ISO-8859-1',on_bad_lines='skip')

# %%
#dataset_t2=dataset_t1.dropna()

# %%
#dataset_t2['joined_column'] = dataset_t2['Question'] + ' ' + dataset_t2['Answer']
#dataset_t3 =dataset_t2[["joined_column"]]

# %%
#dataset_t3

# %%
#dataset_t3.info()

# %%
# import re

# from nltk.corpus import stopwords

# from nltk.tokenize import word_tokenize

# from nltk.stem import WordNetLemmatizer

# lemmatizer = WordNetLemmatizer() # lemma

# import spacy

# nlp = spacy.load('en_core_web_sm')

# corpus = []

# text = list(dataset_t3['joined_column']) # for cleaning purposes

# numwords = {
#     "zero": 0, "one": 1, "two": 2, "three": 3, "four": 4, "five": 5, "six": 6, "seven": 7, "eight": 8, "nine": 9,
#     "ten": 10, "eleven": 11, "twelve": 12, "thirteen": 13, "fourteen": 14, "fifteen": 15, "sixteen": 16,
#     "seventeen": 17, "eighteen": 18, "nineteen": 19,
#     "twenty": 20, "thirty": 30, "forty": 40, "fifty": 50, "sixty": 60, "seventy": 70, "eighty": 80, "ninety": 90,
#     "hundred": 100, "thousand": 1000, "million": 1000000, "billion": 1000000000, "trillion": 1000000000000,
# }

# for i in range(len(text)):

#     r = re.sub('[^a-zA-Z]', ' ', text[i])
#     r = re.sub(r"(\w)([.,;:!?'\"”\)])", r"\1 \2", text[i])
#     r = re.sub(r"(\w)([.,;:!?'\"”\)])", r"\1 \2", text[i])
    
#     r = re.sub(r"n\'t", " not", r)
#     r = re.sub(r"\'re", " are", r)
#     r = re.sub(r"\'s", " is", r)
#     r = re.sub(r"\'d", " would", r)
#     r = re.sub(r"\'ll", " will", r)
#     r = re.sub(r"\'t", " not", r)
#     r = re.sub(r"\'ve", " have", r)
#     r = re.sub(r"\'m", " am", r)

#     r = re.sub(r"n\’t", " not", r)
#     r = re.sub(r"\’re", " are", r)
#     r = re.sub(r"\’s", " is", r)
#     r = re.sub(r"\’d", " would", r)
#     r = re.sub(r"\’ll", " will", r)
#     r = re.sub(r"\’t", " not", r)
#     r = re.sub(r"\’ve", " have", r)
#     r = re.sub(r"\’m", " am", r)
    
#     # Convert text to integer
#     textnum = r.replace('-', ' ')
#     words = textnum.split()
#     result = 0
#     current = 0

#     for word in words:
#         if word in numwords:
#             num = numwords[word]
#             if num == 100:
#                 current *= num
#             else:
#                 current += num
#         elif word == 'and':
#             continue
#         else:
#             if current != 0:
#                 result += current
#                 current = 0

#     r = r.lower()

#     r = r.split()

#     r = [word for word in r if word not in stopwords.words('english')]

#     doc = nlp(text[i])
    
#     r = [token.lemma_ for token in doc]

#     r = ' '.join(r)

#     corpus.append(r)

# dataset_t3['joined_column'] = corpus

# dataset_t3.head()

# %%
# # Preprocessing steps
# X = dataset_t3['joined_column']

# X_feature_vectors = []  # Store the feature vectors for X

# for text in X:
#     #tokens = text.split() 
#     tokens = word_tokenize(text)
#     feature_dict = {}  # Local feature vector in dict form
#     for w in tokens:
#         if w in feature_dict:
#             feature_dict[w] = feature_dict[w] + 1  # Add weight based on occurrence
#         else:
#             feature_dict[w] = 1  # Assigning 1 to word weight
#     X_feature_vectors.append(feature_dict)

# # Convert X_feature_vectors into a sparse matrix

# dict_vectorizer = DictVectorizer(sparse=True)
# X_custom_features = dict_vectorizer.fit_transform(X_feature_vectors)

# %%
# # Create a TF-IDF vectorizer
# tfidf_vectorizer = TfidfVectorizer(max_features=7024)
# X_tfidf = tfidf_vectorizer.fit_transform(X)
# X_combined = hstack([X_tfidf, X_custom_features])

# %%
# max_features = 7024

# # Select a subset of features from X_tfidf
# X_tfidf_subset = X_tfidf[:, :max_features]

# # Select a subset of features from X_custom_features
# X_custom_features_subset = X_custom_features[:, :max_features]

# # Horizontally stack the two subsets
# X_combined = np.hstack([X_tfidf_subset, X_custom_features_subset])

# %%
#y_pred = ensemble_model.predict(X_combined)

# %%
#datasetl = dataset_t2['Label']

# %%
# # Calculate evaluation metrics
# accuracy = accuracy_score(datasetl , y_pred)
# precision = precision_score(datasetl , y_pred, average='weighted', zero_division=0)
# recall = recall_score(datasetl , y_pred, average='weighted')
# f1 = f1_score(datasetl , y_pred, average='weighted', zero_division=0)
# classification_rep = classification_report(datasetl , y_pred, target_names=label_encoder.classes_, zero_division=0)

# metrics = {
#     'Accuracy': accuracy,
#     'Precision': precision,
#     'Recall': recall,
#     'F1': f1,
#     'Classification Report': classification_rep
# }

# print(f'Accuracy: {metrics["Accuracy"]:.4f}')
# print(f'Precision: {metrics["Precision"]:.4f}')
# print(f'Recall: {metrics["Recall"]:.4f}')
# print(f'F1-score: {metrics["F1"]:.4f}')
# print(f'Classification Report:\n{metrics["Classification Report"]}')

# %%
# # Define your labels as a list of strings
# labels = ['analysis', 'science and tech', 'factual', 'taxonomy', 'strategy', 'ethics and regulation', 'management']

# # Assuming y_test contains the true labels for the test set and y_pred contains predicted labels
# # Define a mapping from numerical labels to string labels
# label_mapping = {i: label for i, label in enumerate(labels)}

# # Use list comprehension to convert numerical labels to string labels
# y_pred_strings = [label_mapping[label] for label in y_pred]

# %%
# # Define your labels as a list of strings
# labels = ['analysis', 'science and tech', 'factual', 'taxonomy', 'strategy', 'ethics and regulation', 'management']

# # Assuming y_test contains the true labels for the test set and y_pred contains predicted labels
# # Define a mapping from numerical labels to string labels
# label_mapping = {i: label for i, label in enumerate(datasetl)
#                 }# Use list comprehension to convert numerical labels to string labels
# y_chatgpt_strings = [label_mapping[label] for label in y_pred]

# %%
# # Zip the two lists together
# zipped_strings = list(zip(y_pred_strings, y_chatgpt_strings))

# # Display the pairs side by side
# for pred, chatgpt in zipped_strings:
#     print(f'{pred}\t{chatgpt}')
